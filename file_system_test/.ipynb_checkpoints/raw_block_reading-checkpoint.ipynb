# %%
import struct
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
os.listdir('/dev')
# Out:
# ['rfkill',
#  'vga_arbiter',
#  'mem',
#  'null',
#  'port',
#  'zero',
#  'full',
#  'random',
#  'urandom',
#  'kmsg',
#  'tty',
#  'console',
#  'tty0',
#  'vcs',
#  'vcsu',
#  'vcsa',
#  'vcs1',
#  'vcsu1',
#  'vcsa1',
#  'tty1',
#  'tty2',
#  'tty3',
#  'tty4',
#  'tty5',
#  'tty6',
#  'tty7',
#  'tty8',
#  'tty9',
#  'tty10',
#  'tty11',
#  'tty12',
#  'tty13',
#  'tty14',
#  'tty15',
#  'tty16',
#  'tty17',
#  'tty18',
#  'tty19',
#  'tty20',
#  'tty21',
#  'tty22',
#  'tty23',
#  'tty24',
#  'tty25',
#  'tty26',
#  'tty27',
#  'tty28',
#  'tty29',
#  'tty30',
#  'tty31',
#  'tty32',
#  'tty33',
#  'tty34',
#  'tty35',
#  'tty36',
#  'tty37',
#  'tty38',
#  'tty39',
#  'tty40',
#  'tty41',
#  'tty42',
#  'tty43',
#  'tty44',
#  'tty45',
#  'tty46',
#  'tty47',
#  'tty48',
#  'tty49',
#  'tty50',
#  'tty51',
#  'tty52',
#  'tty53',
#  'tty54',
#  'tty55',
#  'tty56',
#  'tty57',
#  'tty58',
#  'tty59',
#  'tty60',
#  'tty61',
#  'tty62',
#  'tty63',
#  'hwrng',
#  'snapshot',
#  'userfaultfd',
#  'ecryptfs',
#  'fuse',
#  'ptmx',
#  'ttyS0',
#  'ttyS1',
#  'ttyS2',
#  'ttyS3',
#  'ttyS4',
#  'ttyS5',
#  'ttyS6',
#  'ttyS7',
#  'ttyS8',
#  'ttyS9',
#  'ttyS10',
#  'ttyS11',
#  'ttyS12',
#  'ttyS13',
#  'ttyS14',
#  'ttyS15',
#  'ttyS16',
#  'ttyS17',
#  'ttyS18',
#  'ttyS19',
#  'ttyS20',
#  'ttyS21',
#  'ttyS22',
#  'ttyS23',
#  'ttyS24',
#  'ttyS25',
#  'ttyS26',
#  'ttyS27',
#  'ttyS28',
#  'ttyS29',
#  'ttyS30',
#  'ttyS31',
#  'ttyprintk',
#  'hpet',
#  'tpm0',
#  'loop-control',
#  'loop0',
#  'loop1',
#  'loop2',
#  'loop3',
#  'loop4',
#  'loop5',
#  'loop6',
#  'loop7',
#  'dma_heap',
#  'udmabuf',
#  'net',
#  'ppp',
#  'input',
#  'psaux',
#  'uinput',
#  'rtc0',
#  'mapper',
#  'mcelog',
#  'cpu_dma_latency',
#  'pts',
#  'char',
#  'bus',
#  'i2c-0',
#  'rtc',
#  'block',
#  'ptp0',
#  'sg0',
#  'bsg',
#  'sda',
#  'sda1',
#  'sda2',
#  'sda3',
#  'sda4',
#  'sda5',
#  'sda6',
#  'i2c-1',
#  'i2c-2',
#  'i2c-3',
#  'i2c-4',
#  'i2c-5',
#  'i2c-6',
#  'sr0',
#  'sg1',
#  'disk',
#  'dri',
#  'drm_dp_aux0',
#  'i2c-7',
#  'drm_dp_aux1',
#  'i2c-8',
#  'fb0',
#  'autofs',
#  'shm',
#  'core',
#  'fd',
#  'stdin',
#  'stdout',
#  'stderr',
#  'initctl',
#  'log',
#  'hugepages',
#  'mqueue',
#  'cpu',
#  'cuse',
#  'btrfs-control',
#  'nvram',
#  'userio',
#  'uhid',
#  'vfio',
#  'vhci',
#  'vhost-net',
#  'vhost-vsock',
#  'snd',
#  'zfs',
#  'loop8',
#  'loop9',
#  'loop11',
#  'loop10',
#  'loop13',
#  'loop12',
#  'loop14',
#  'loop15',
#  'mei0',
#  'vboxusb',
#  'mtd0',
#  'mtd0ro',
#  'mtd1',
#  'mtd1ro',
#  'cdc-wdm1',
#  'kvm',
#  'video0',
#  'video1',
#  'media0',
#  'v4l',
#  'vcs2',
#  'vcsu2',
#  'vcsa2',
#  'vcs3',
#  'vcsu3',
#  'vcsa3',
#  'vcs4',
#  'vcsu4',
#  'vcsa4',
#  'vcs5',
#  'vcsu5',
#  'vcsa5',
#  'vcs6',
#  'vcsu6',
#  'vcsa6',
#  'ptp1',
#  'loop16',
#  'vboxdrv',
#  'vboxdrvu',
#  'vboxnetctl',
#  'cdrom',
#  'loop17',
#  'hidraw0',
#  'usb',
#  'hidraw1',
#  'hidraw2',
#  'mmcblk0']

# %%
device = '/dev/mmcblk0'

# %% [markdown]
# für den Zugriff ist folgendes Kommando notwendig
#
# sudo chmod 777 /dev/mmcblk0

# %%
# !ls -l {device}
# Out:
# brw-rw---- 1 root disk 179, 0 Feb 19 13:32 /dev/mmcblk0

# %%
# !ls
# Out:
# card			     raw_write_test.py	   speed_test.dat
# card_test.py		     README		   speed_test.py
# doc			     sdcard_dev.py	   sudo
# example_vfs_ram_littlefs.py  sdcard.py		   vfs_fat_test.py
# raw_block_timing.ipynb	     SD_card_timing.ipynb  vfs_littlefs_test.py
